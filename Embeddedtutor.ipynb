# %%
# importing the required module
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from scipy.stats import gaussian_kde
from statistics import mean, stdev
from scipy.stats import sem
import scipy.stats as stats

# %%
#Optional for disabling warnings
import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
#Set figure resolution to 300dpi
import matplotlib as mpl
# %matplotlib inline
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
df = pd.read_excel (r'./Fall24_Bio212.xlsx', index_col=0)
df.describe()
# Out:
#                   ID  SIS User ID     Exam 1  Exam1_percent  Exam1_score  \
# count      28.000000         27.0  23.000000      23.000000    23.000000
# mean   170879.571429  900000000.0  57.000000       0.703704    70.370370
# std     78946.472902          0.0  15.612495       0.192747    19.274685
# min      2673.000000  900000000.0  25.000000       0.308642    30.864198
# 25%    171982.250000  900000000.0  45.500000       0.561728    56.172840
# 50%    198200.000000  900000000.0  56.000000       0.691358    69.135802
# 75%    221233.750000  900000000.0  71.000000       0.876543    87.654321
# max    242753.000000  900000000.0  79.000000       0.975309    97.530864
#
#        Study_Guide_avg  Non_Study_Guide_avg
# count         5.000000            18.000000
# mean         84.444444            66.460905
# std           9.222148            19.655259
# min          75.308642            30.864198
# 25%          75.308642            54.320988
# 50%          85.185185            62.654321
# 75%          90.123457            81.018519
# max          96.296296            97.530864

# %%
# Plot Histogram on x
x1 = df['Exam1_score'].dropna()

# Define number of bins for the histogram
bins = 25

# Plot histogram with actual frequency (density=False)
count_x1, bins_x1, _ = plt.hist(x1, bins=bins, edgecolor='k', alpha=0.6, density=False)
plt.gca().set(title='Fall 2024 - Exam 1 Score (No embedded tutor)', ylabel='Frequency', xlabel='Score (%)')
plt.xlim(0, 100)

# Add KDE curve
kde_x1 = gaussian_kde(x1)
x1_range = np.linspace(0, 100, 1000)  # Generate x-values for KDE curve

# Scale KDE by the number of data points and the bin width to match the histogram's frequency scale
bin_width_x1 = bins_x1[1] - bins_x1[0]
plt.plot(x1_range, kde_x1(x1_range) * len(x1) * bin_width_x1, color='r', linewidth=2)

# Plot vertical line for mean
plt.axvline(x1.mean(), color='k', linestyle='dashed', linewidth=1)

# Add mean text
min_ylim, max_ylim = plt.ylim()
plt.text(x1.mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(x1.mean()))

# Display the plot
plt.show()

# %%
df2 = pd.read_csv (r'./2025-10-12T0355_Grades-BIO_212_(70900).csv', index_col=0)
df2.describe()
# Out:
#                   ID   SIS User ID  Exercise: Introduce Yourself (885750)  \
# count      31.000000  3.000000e+01                                   30.0
# mean   196557.225806  9.003103e+08                                    2.5
# std     66456.717283  6.988199e+04                                    0.0
# min      2890.000000  9.000706e+08                                    2.5
# 25%    192569.000000  9.003121e+08                                    2.5
# 50%    210345.000000  9.003300e+08                                    2.5
# 75%    236848.500000  9.003504e+08                                    2.5
# max    254210.000000  9.003701e+08                                    2.5
#
#        SUBMIT: Optional Unit 1 Study Guide Here (885613)  \
# count                                          14.000000
# mean                                            0.464286
# std                                             0.133631
# min                                             0.000000
# 25%                                             0.500000
# 50%                                             0.500000
# 75%                                             0.500000
# max                                             0.500000
#
#        SUBMIT: Optional Unit 2 Study Guide Here (885614)  \
# count                                          15.000000
# mean                                            0.466667
# std                                             0.129099
# min                                             0.000000
# 25%                                             0.500000
# 50%                                             0.500000
# 75%                                             0.500000
# max                                             0.500000
#
#        SUBMIT: Optional Unit 3 Study Guide Here (885615)  \
# count                                                1.0
# mean                                                 0.0
# std                                                  NaN
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        SUBMIT: Optional Unit 4 Study Guide Here (885617)  \
# count                                                1.0
# mean                                                 0.0
# std                                                  NaN
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        SUBMIT: Optional Unit 5 Study Guide Here (885618)  \
# count                                                1.0
# mean                                                 0.0
# std                                                  NaN
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        SUBMIT: Optional Unit 6 Study Guide Here (885619)  \
# count                                                1.0
# mean                                                 0.0
# std                                                  NaN
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        Unit 3 Exam (885595)  ...  Homework 9 Quiz (885599)  \
# count              5.000000  ...                       1.0
# mean               7.704000  ...                       2.5
# std                1.779306  ...                       NaN
# min                5.590000  ...                       2.5
# 25%                6.690000  ...                       2.5
# 50%                7.240000  ...                       2.5
# 75%                9.000000  ...                       2.5
# max               10.000000  ...                       2.5
#
#        Homework 10 Quiz (885590)  Homework 11 Quiz (885580)  \
# count                        1.0                        1.0
# mean                         2.5                        2.5
# std                          NaN                        NaN
# min                          2.5                        2.5
# 25%                          2.5                        2.5
# 50%                          2.5                        2.5
# 75%                          2.5                        2.5
# max                          2.5                        2.5
#
#        Homework 12 Quiz (885585)  Homework 13 Quiz (885579)  \
# count                        1.0                        1.0
# mean                         2.5                        2.5
# std                          NaN                        NaN
# min                          2.5                        2.5
# 25%                          2.5                        2.5
# 50%                          2.5                        2.5
# 75%                          2.5                        2.5
# max                          2.5                        2.5
#
#        Homework 14 Quiz (885581)  Unit 1 Exam (885621)  Unit 2 Exam (885622)  \
# count                        1.0             31.000000             29.000000
# mean                         2.5              7.785161              7.843103
# std                          NaN              1.427807              1.160240
# min                          2.5              5.130000              6.190000
# 25%                          2.5              6.630000              6.980000
# 50%                          2.5              7.630000              7.620000
# 75%                          2.5              8.970000              8.570000
# max                          2.5             10.130000             10.000000
#
#        Unit 4 Exam (885624)  Unit 6 Exam (Final Exam) (885626)
# count                   1.0                                1.0
# mean                   10.0                               10.0
# std                     NaN                                NaN
# min                    10.0                               10.0
# 25%                    10.0                               10.0
# 50%                    10.0                               10.0
# 75%                    10.0                               10.0
# max                    10.0                               10.0
#
# [8 rows x 30 columns]

# %%
# Plot Histogram on x
x2 = df2['Unit 1 Exam (885621)'].dropna()*10
x2 = x2[x2 != 0]

# Define number of bins for the histogram
bins = 25

# Plot histogram with actual frequency (density=False)
count_x2, bins_x2, _ = plt.hist(x2, bins=bins, edgecolor='k', alpha=0.6, density=False)
plt.gca().set(title='Fall 2025 - Exam 1 Score (With embedded tutor)', ylabel='Frequency', xlabel='Score (%)')
plt.xlim(0, 100)

# Add KDE c ve
kde_x2 = gaussian_kde(x2)
x2_range = np.linspace(0, 100, 1000)  # Generate x-values for KDE curve

# Scale KDE by the number of data points and the bin width to match the histogram's frequency scale
bin_width_x2 = bins_x2[1] - bins_x2[0]
plt.plot(x2_range, kde_x2(x2_range) * len(x2) * bin_width_x2, color='r', linewidth=2)

# Plot vertical line for mean
plt.axvline(x2.mean(), color='k', linestyle='dashed', linewidth=1)

# Add mean text
min_ylim, max_ylim = plt.ylim()
plt.text(x2.mean()*1.01, max_ylim*0.9, 'Mean: {:.2f}'.format(x2.mean()))

# Display the plot
plt.show()

# %%
# make x1 x3
x3 = x1

bins = np.linspace(0, 100, 8)
plt.figure(figsize=(10, 7), dpi=300)

# Histograms (density)
plt.hist(x3, bins=bins, density=True, alpha=0.4, edgecolor='k', label="Without embedded tutor", color="black")
plt.hist(x2, bins=bins, density=True, alpha=0.4, edgecolor='k', label="With embedded tutor", color="dodgerblue")

# KDE on density scale
x_grid = np.linspace(0, 100, 1000)
kde2 = gaussian_kde(x2)
kde3 = gaussian_kde(x3)
plt.plot(x_grid, kde2(x_grid), linewidth=3, color="dodgerblue")
plt.plot(x_grid, kde3(x_grid), linewidth=3, color="black")

plt.axvline(x2.mean(), linestyle='dashed', linewidth=1, color="dodgerblue")
plt.axvline(x3.mean(), linestyle='dashed', linewidth=1, color="black")

# Add text labels for means
min_ylim, max_ylim = plt.ylim()
plt.text(x2.mean() * 1.015, max_ylim * 0.965, 'Mean: {:.2f}'.format(x2.mean()), color="dodgerblue")
plt.text(x3.mean() * .845, max_ylim * 0.965, 'Mean: {:.2f}'.format(x3.mean()), color="black")

plt.xlim(0, 100)
plt.legend()
plt.title('Human Biology - Lecture Exam 1 - Without and With Embedded Tutor')
plt.xlabel('Score (%)')
plt.ylabel('Density')
plt.tight_layout()
plt.show()
